# %%
import subprocess
import numpy as np
import os
import pickle as pkl
import re
import ast
import json
import math
from tqdm.notebook import tqdm

def parse_metrics(command):
    # Run the command using subprocess in Jupyter
    try:
        result = subprocess.run(command, check=True, capture_output=True, text=True)
        # print("Output:\n", result.stdout)
    except subprocess.CalledProcessError as e:
        print("Error occurred:\n", e.stderr)

    # Split the output into lines
    output_lines = result.stdout.strip().split('\n')
    # print(output_lines)

    # Iterate over the lines to find metrics
    for i, line in enumerate(output_lines):
        if 'Metrics before applying QB-Norm' in line:
            # The next line contains the metrics dictionary
            if i + 1 < len(output_lines):
                metrics_line = output_lines[i + 1].strip()
                try:
                    metrics_before = ast.literal_eval(metrics_line)
                except (SyntaxError, ValueError):
                    print(f"Could not parse metrics before at line {i + 1}: {metrics_line}")
        elif 'Metrics after QB-Norm' in line:
            # The next line contains the metrics dictionary
            if i + 1 < len(output_lines):
                metrics_line = output_lines[i + 1].strip()
                try:
                    metrics_after = ast.literal_eval(metrics_line)
                except (SyntaxError, ValueError):
                    print(f"Could not parse metrics after at line {i + 1}: {metrics_line}")

    # # Now you have lists of metrics dictionaries
    # print("Metrics Before QB-Norm:", metrics_before_list)
    # print("Metrics After QB-Norm:", metrics_after_list)

    # Save the metrics into a variable
    metrics = {
        'before': metrics_before,
        'after': metrics_after
    }
    return metrics

def execute_dynamic_inverted_softmax(test_file_path, train_file_path, adv_test_similarity_path, adv_train_similarity_path, gt_idx_path, out_dir):
    out_dir=out_dir+"/output_cache"
    # Load data from file
    data = np.load(test_file_path, allow_pickle=True)  # Load the data as a NumPy array
    train_data = np.load(train_file_path, allow_pickle=True)  # Load the data as a NumPy array
    # Load adversarial similarity matrices
    adv_test_similarity_matrices = np.load(adv_test_similarity_path, allow_pickle=True)
    adv_train_similarity_matrices = np.load(adv_train_similarity_path, allow_pickle=True)

    gt_idx=np.load(gt_idx_path, allow_pickle=True)
    
    # Create temp directory if it doesn't exist
    os.makedirs(out_dir, exist_ok=True)
    
    gt_metrics = {}
    adv_metrics = {}
    # Iterate over adversarial matrices, modify data, save with different names, and execute command
    for i, adv in enumerate(tqdm(adv_test_similarity_matrices[:100])):
        # print("Adv shape:", adv.shape)
        test_data_temp = data.copy()
        test_data_temp = np.column_stack((test_data_temp, adv.flatten()))        
        # Save the modified data to a new file with different names in temp directory
        modified_file_path = f'{out_dir}/modified-test-images-texts-seed0-{i}.pkl'
        with open(modified_file_path, 'wb') as f:
            pkl.dump(test_data_temp, f)
        # print(f"Modified data saved to {modified_file_path}")

        train_data_temp = train_data.copy()
        flattened_column = adv_train_similarity_matrices[i].flatten()
        train_data_temp = np.column_stack((train_data_temp, flattened_column))
        # save the modified train data to a new file with different names in temp directory
        modified_train_file_path = f'{out_dir}/modified-train-images-texts-seed0-{i}.pkl'
        with open(modified_train_file_path, 'wb') as f:
            pkl.dump(train_data_temp, f)

        num_queries, num_vids = test_data_temp.shape
        queries_per_video =  math.ceil(num_queries / num_vids)
        adv_idx = np.array([
            [num_vids * (ii + jj * queries_per_video) + num_vids - 1 for ii in range(queries_per_video)]
            for jj in range(num_vids-1)
        ])

        adv_idx_path = f'{out_dir}/adv_idx.pkl'
        with open(adv_idx_path, 'wb') as f:
            pkl.dump(adv_idx, f)
        # print(f"adv_idx saved to {adv_idx_path}")

        modified_gt_index = gt_idx.copy()
        temp_shape = modified_gt_index.shape
        modified_gt_index = modified_gt_index.flatten() + np.arange(modified_gt_index.size)
        modified_gt_index = modified_gt_index.reshape(temp_shape)

        modified_gt_index_path=f'{out_dir}/modified_gt_idx-{i}.pkl'
        with open(modified_gt_index_path, 'wb') as f:
            pkl.dump(modified_gt_index, f)
        # print(f"modified_gt_idx saved to {modified_gt_index_path}")

        # Define the command and arguments for each modified data file
        gt_command = [
            'python', 'dynamic_inverted_softmax.py',
            '--sims_train_test_path', modified_train_file_path,
            '--sims_test_path', modified_file_path,
            '--gt_idx_path', modified_gt_index_path,
            '--defense', 'True'

        ]

        adv_command = [
            'python', 'dynamic_inverted_softmax.py',
            '--sims_train_test_path', modified_train_file_path,
            '--sims_test_path', modified_file_path,
            '--gt_idx_path', adv_idx_path,
            '--defense', 'True'
        ]
        
        # Run the command
        gt_metrics[i]=parse_metrics(gt_command)
        print(gt_metrics[i])

        adv_metrics[i]=parse_metrics(adv_command)
        print(adv_metrics[i])
        
        # save the metrics to a file
        with open(f'{out_dir}/gt_metrics.pkl', 'wb') as f:
            pkl.dump(gt_metrics, f)
        with open(f'{out_dir}/adv_metrics.pkl', 'wb') as f:
            pkl.dump(adv_metrics, f)

        # Remove the modified data files
        os.remove(modified_file_path)
        
    return gt_metrics, adv_metrics

# %%
out_dir = '../outputs/mscoco/openclip'
test_file_path = f'{out_dir}/test_similarity_matrix.pkl'
train_file_path = f'{out_dir}/train_similarity_matrix.pkl'
adv_test_similarity_path = f'{out_dir}/adv_test_similarity_matrix.pkl'
adv_train_similarity_path = f'{out_dir}/adv_train_similarity_matrix.pkl'

# print the shape of the similarity matrices
test_data = np.load(test_file_path, allow_pickle=True)
train_data = np.load(train_file_path, allow_pickle=True)
adv_test_similarity_matrices = np.load(adv_test_similarity_path, allow_pickle=True)
adv_train_similarity_matrices = np.load(adv_train_similarity_path, allow_pickle=True)
print("Test data shape:", test_data.shape)
print("Train data shape:", train_data.shape)
print("Adv test similarity matrices shape:", adv_test_similarity_matrices.shape)
print("Adv train similarity matrices shape:", adv_train_similarity_matrices.shape)

gt_idx_path='../outputs/mscoco/gt_idx.pkl'

os.makedirs(out_dir, exist_ok=True)

# Define the command and arguments
command = [
    'python', 'dynamic_inverted_softmax.py',
    '--sims_train_test_path', train_file_path,
    '--sims_test_path', test_file_path,
    '--gt_idx_path', gt_idx_path,
    '--defense', 'True'
]

print(command)
# Parse the metrics
metrics = parse_metrics(command)
print("Mertrics for original data:")
print(metrics)
# Out:
# Test data shape: (25000, 5000)
# Train data shape: (5000, 5000)
# Adv test similarity matrices shape: (25000, 100)
# Adv train similarity matrices shape: (100, 5000)
# ['python', 'dynamic_inverted_softmax.py', '--sims_train_test_path', '../outputs/mscoco/openclip/train_similarity_matrix.pkl', '--sims_test_path', '../outputs/mscoco/openclip/test_similarity_matrix.pkl', '--gt_idx_path', '../outputs/mscoco/gt_idx.pkl', '--defense', 'True']
# Mertrics for original data:
# {'before': {'R1': 48.5, 'R3': 65.8, 'R5': 72.8, 'R10': 81.1, 'R50': 95.3, 'MedR': 2.0, 'MeanR': 13.8, 'geometric_mean_R1-R5-R10': 65.9, 'MeanA': 0.311}, 'after': {'R1': 50.0, 'R3': 66.8, 'R5': 73.9, 'R10': 82.3, 'R50': 95.6, 'MedR': 2.0, 'MeanR': 13.2, 'geometric_mean_R1-R5-R10': 67.2, 'MeanA': 0.131}}

# %%
gt_metrics, adv_metrics = execute_dynamic_inverted_softmax(test_file_path, train_file_path, adv_test_similarity_path, adv_train_similarity_path, gt_idx_path, out_dir)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'before': {'R1': 9.5, 'R3': 28.0, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.8, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.2, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.032}}
# {'before': {'R1': 63.7, 'R3': 81.1, 'R5': 86.2, 'R10': 92.0, 'R50': 98.8, 'MedR': 1.0, 'MeanR': 4.3, 'geometric_mean_R1-R5-R10': 79.7, 'MeanA': 0.285}, 'after': {'R1': 0.0, 'R3': 6.1, 'R5': 7.7, 'R10': 9.3, 'R50': 11.3, 'MedR': 1421.5, 'MeanR': 1816.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 3.2, 'R3': 27.0, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 17.8, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.016}}
# {'before': {'R1': 90.4, 'R3': 97.0, 'R5': 98.3, 'R10': 99.2, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.5, 'geometric_mean_R1-R5-R10': 95.9, 'MeanA': 0.321}, 'after': {'R1': 0.0, 'R3': 3.5, 'R5': 4.2, 'R10': 4.6, 'R50': 5.3, 'MedR': 1490.0, 'MeanR': 1973.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.014}}
# {'before': {'R1': 5.2, 'R3': 27.4, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.1, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.7, 'R10': 62.2, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.023}}
# {'before': {'R1': 81.5, 'R3': 91.1, 'R5': 93.8, 'R10': 96.3, 'R50': 99.5, 'MedR': 1.0, 'MeanR': 2.5, 'geometric_mean_R1-R5-R10': 90.3, 'MeanA': 0.313}, 'after': {'R1': 0.0, 'R3': 4.5, 'R5': 5.5, 'R10': 6.5, 'R50': 8.1, 'MedR': 1570.5, 'MeanR': 2050.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.02}}
# {'before': {'R1': 7.8, 'R3': 27.8, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 24.2, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.4, 'R5': 50.4, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 68.7, 'R3': 83.1, 'R5': 87.6, 'R10': 92.2, 'R50': 98.5, 'MedR': 1.0, 'MeanR': 4.9, 'geometric_mean_R1-R5-R10': 82.2, 'MeanA': 0.292}, 'after': {'R1': 0.0, 'R3': 5.1, 'R5': 6.5, 'R10': 7.9, 'R50': 9.9, 'MedR': 1364.0, 'MeanR': 1898.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.025}}
# {'before': {'R1': 8.2, 'R3': 28.0, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.5, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.3, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.03}}
# {'before': {'R1': 64.8, 'R3': 81.2, 'R5': 86.4, 'R10': 92.1, 'R50': 99.1, 'MedR': 1.0, 'MeanR': 4.0, 'geometric_mean_R1-R5-R10': 80.2, 'MeanA': 0.288}, 'after': {'R1': 0.0, 'R3': 5.8, 'R5': 7.3, 'R10': 8.7, 'R50': 10.4, 'MedR': 1355.0, 'MeanR': 1754.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 8.4, 'R3': 28.3, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.8, 'MeanA': 0.236}, 'after': {'R1': 26.5, 'R3': 42.3, 'R5': 50.2, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.029}}
# {'before': {'R1': 64.2, 'R3': 78.5, 'R5': 83.6, 'R10': 89.4, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 5.1, 'geometric_mean_R1-R5-R10': 78.3, 'MeanA': 0.29}, 'after': {'R1': 0.0, 'R3': 4.6, 'R5': 6.1, 'R10': 7.6, 'R50': 10.2, 'MedR': 1782.0, 'MeanR': 2075.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.025}}
# {'before': {'R1': 10.3, 'R3': 28.4, 'R5': 36.9, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.034}}
# {'before': {'R1': 58.1, 'R3': 76.1, 'R5': 82.0, 'R10': 88.9, 'R50': 98.2, 'MedR': 1.0, 'MeanR': 5.6, 'geometric_mean_R1-R5-R10': 75.1, 'MeanA': 0.281}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.6, 'R10': 9.3, 'R50': 11.9, 'MedR': 1307.5, 'MeanR': 1783.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 7.8, 'R3': 27.8, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 24.1, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.03}}
# {'before': {'R1': 69.0, 'R3': 83.6, 'R5': 88.1, 'R10': 93.0, 'R50': 98.8, 'MedR': 1.0, 'MeanR': 3.9, 'geometric_mean_R1-R5-R10': 82.7, 'MeanA': 0.294}, 'after': {'R1': 0.0, 'R3': 5.6, 'R5': 7.0, 'R10': 8.7, 'R50': 11.1, 'MedR': 1547.0, 'MeanR': 1997.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.027}}
# {'before': {'R1': 7.8, 'R3': 28.0, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.2, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.027}}
# {'before': {'R1': 66.8, 'R3': 80.2, 'R5': 84.8, 'R10': 90.1, 'R50': 97.9, 'MedR': 1.0, 'MeanR': 5.2, 'geometric_mean_R1-R5-R10': 79.9, 'MeanA': 0.293}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.2, 'R10': 7.5, 'R50': 9.8, 'MedR': 1863.0, 'MeanR': 2159.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.023}}
# {'before': {'R1': 1.6, 'R3': 26.9, 'R5': 36.3, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 14.2, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.8, 'R10': 62.5, 'R50': 87.1, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 44.0, 'MeanA': 0.01}}
# {'before': {'R1': 96.2, 'R3': 98.8, 'R5': 99.2, 'R10': 99.6, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.2, 'geometric_mean_R1-R5-R10': 98.3, 'MeanA': 0.355}, 'after': {'R1': 0.0, 'R3': 1.9, 'R5': 2.2, 'R10': 2.5, 'R50': 2.8, 'MedR': 1706.0, 'MeanR': 2120.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.007}}
# {'before': {'R1': 10.1, 'R3': 28.4, 'R5': 37.0, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.2, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.033}}
# {'before': {'R1': 56.2, 'R3': 74.1, 'R5': 80.2, 'R10': 87.0, 'R50': 97.5, 'MedR': 1.0, 'MeanR': 6.5, 'geometric_mean_R1-R5-R10': 73.2, 'MeanA': 0.278}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.1, 'R10': 8.9, 'R50': 11.7, 'MedR': 1371.5, 'MeanR': 1865.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.029}}
# {'before': {'R1': 2.0, 'R3': 26.9, 'R5': 36.3, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 15.3, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.8, 'R10': 62.5, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.011}}
# {'before': {'R1': 94.1, 'R3': 97.9, 'R5': 98.7, 'R10': 99.3, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.4, 'geometric_mean_R1-R5-R10': 97.3, 'MeanA': 0.345}, 'after': {'R1': 0.0, 'R3': 2.1, 'R5': 2.5, 'R10': 2.9, 'R50': 3.7, 'MedR': 1814.0, 'MeanR': 2175.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.008}}
# {'before': {'R1': 10.0, 'R3': 28.5, 'R5': 37.0, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.3, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.3, 'R5': 50.1, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.034}}
# {'before': {'R1': 55.5, 'R3': 74.0, 'R5': 80.5, 'R10': 87.5, 'R50': 97.2, 'MedR': 1.0, 'MeanR': 6.7, 'geometric_mean_R1-R5-R10': 73.1, 'MeanA': 0.279}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.3, 'R10': 9.1, 'R50': 12.0, 'MedR': 1307.0, 'MeanR': 1817.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 15.2, 'R3': 30.0, 'R5': 37.9, 'R10': 49.7, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 30.6, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.1, 'R5': 50.0, 'R10': 61.6, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.041}}
# {'before': {'R1': 27.2, 'R3': 44.6, 'R5': 53.2, 'R10': 65.2, 'R50': 91.5, 'MedR': 5.0, 'MeanR': 16.1, 'geometric_mean_R1-R5-R10': 45.5, 'MeanA': 0.248}, 'after': {'R1': 0.0, 'R3': 4.6, 'R5': 6.7, 'R10': 9.2, 'R50': 14.0, 'MedR': 1381.0, 'MeanR': 1774.8, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.035}}
# {'before': {'R1': 10.0, 'R3': 28.3, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.3, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.033}}
# {'before': {'R1': 58.6, 'R3': 75.3, 'R5': 81.3, 'R10': 88.0, 'R50': 98.0, 'MedR': 1.0, 'MeanR': 5.7, 'geometric_mean_R1-R5-R10': 74.8, 'MeanA': 0.281}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.2, 'R10': 8.9, 'R50': 11.7, 'MedR': 1435.5, 'MeanR': 1849.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.029}}
# {'before': {'R1': 11.2, 'R3': 28.7, 'R5': 37.1, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 27.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.2, 'R10': 61.8, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.035}}
# {'before': {'R1': 50.0, 'R3': 69.1, 'R5': 76.5, 'R10': 85.4, 'R50': 98.1, 'MedR': 1.0, 'MeanR': 6.3, 'geometric_mean_R1-R5-R10': 68.9, 'MeanA': 0.272}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.7, 'R10': 9.7, 'R50': 12.4, 'MedR': 1313.5, 'MeanR': 1734.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 10.2, 'R3': 28.3, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.4, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.034}}
# {'before': {'R1': 58.7, 'R3': 76.5, 'R5': 82.2, 'R10': 88.8, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 5.5, 'geometric_mean_R1-R5-R10': 75.4, 'MeanA': 0.281}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.6, 'R10': 9.3, 'R50': 11.9, 'MedR': 1222.0, 'MeanR': 1787.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 8.2, 'R3': 28.0, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.5, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.5, 'R5': 50.4, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 64.2, 'R3': 79.7, 'R5': 84.5, 'R10': 90.1, 'R50': 98.2, 'MedR': 1.0, 'MeanR': 5.1, 'geometric_mean_R1-R5-R10': 78.8, 'MeanA': 0.289}, 'after': {'R1': 0.0, 'R3': 5.2, 'R5': 6.6, 'R10': 8.1, 'R50': 10.7, 'MedR': 1431.0, 'MeanR': 1966.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 9.6, 'R3': 28.2, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.9, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.3, 'R5': 50.2, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.034}}
# {'before': {'R1': 58.5, 'R3': 76.9, 'R5': 82.8, 'R10': 89.1, 'R50': 98.5, 'MedR': 1.0, 'MeanR': 5.3, 'geometric_mean_R1-R5-R10': 75.5, 'MeanA': 0.279}, 'after': {'R1': 0.0, 'R3': 6.3, 'R5': 7.9, 'R10': 9.5, 'R50': 11.8, 'MedR': 1210.5, 'MeanR': 1636.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 7.6, 'R3': 27.9, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 68.9, 'R3': 83.4, 'R5': 87.9, 'R10': 92.6, 'R50': 98.9, 'MedR': 1.0, 'MeanR': 4.0, 'geometric_mean_R1-R5-R10': 82.5, 'MeanA': 0.293}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 6.8, 'R10': 8.2, 'R50': 10.4, 'MedR': 1427.0, 'MeanR': 1890.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.025}}
# {'before': {'R1': 3.7, 'R3': 27.1, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 18.7, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.019}}
# {'before': {'R1': 88.0, 'R3': 95.5, 'R5': 97.2, 'R10': 98.6, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.6, 'geometric_mean_R1-R5-R10': 94.5, 'MeanA': 0.323}, 'after': {'R1': 0.0, 'R3': 3.9, 'R5': 4.7, 'R10': 5.4, 'R50': 6.3, 'MedR': 1604.0, 'MeanR': 2013.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.016}}
# {'before': {'R1': 9.4, 'R3': 28.2, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.7, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.1, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.031}}
# {'before': {'R1': 60.5, 'R3': 77.3, 'R5': 83.0, 'R10': 89.6, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 4.9, 'geometric_mean_R1-R5-R10': 76.6, 'MeanA': 0.283}, 'after': {'R1': 0.0, 'R3': 5.6, 'R5': 7.3, 'R10': 8.9, 'R50': 11.4, 'MedR': 1484.0, 'MeanR': 1878.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 9.6, 'R3': 28.4, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.2, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.033}}
# {'before': {'R1': 60.2, 'R3': 76.5, 'R5': 81.9, 'R10': 87.8, 'R50': 97.0, 'MedR': 1.0, 'MeanR': 6.6, 'geometric_mean_R1-R5-R10': 75.6, 'MeanA': 0.283}, 'after': {'R1': 0.0, 'R3': 5.6, 'R5': 7.3, 'R10': 8.9, 'R50': 11.6, 'MedR': 1384.0, 'MeanR': 1895.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.029}}
# {'before': {'R1': 14.2, 'R3': 29.8, 'R5': 37.8, 'R10': 49.7, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 29.9, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.1, 'R5': 50.0, 'R10': 61.6, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.04}}
# {'before': {'R1': 30.3, 'R3': 47.3, 'R5': 55.5, 'R10': 66.8, 'R50': 90.1, 'MedR': 4.0, 'MeanR': 16.7, 'geometric_mean_R1-R5-R10': 48.3, 'MeanA': 0.251}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.8, 'R10': 9.2, 'R50': 13.8, 'MedR': 1378.0, 'MeanR': 1774.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.035}}
# {'before': {'R1': 13.1, 'R3': 29.3, 'R5': 37.4, 'R10': 49.4, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.2, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.038}}
# {'before': {'R1': 40.1, 'R3': 59.3, 'R5': 67.1, 'R10': 76.9, 'R50': 94.2, 'MedR': 2.0, 'MeanR': 11.9, 'geometric_mean_R1-R5-R10': 59.1, 'MeanA': 0.262}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.0, 'R10': 9.1, 'R50': 13.0, 'MedR': 1267.5, 'MeanR': 1764.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.033}}
# {'before': {'R1': 3.9, 'R3': 27.1, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.1, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.019}}
# {'before': {'R1': 87.6, 'R3': 95.7, 'R5': 97.4, 'R10': 98.7, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.6, 'geometric_mean_R1-R5-R10': 94.4, 'MeanA': 0.316}, 'after': {'R1': 0.0, 'R3': 4.2, 'R5': 4.9, 'R10': 5.6, 'R50': 6.3, 'MedR': 1504.5, 'MeanR': 1969.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.016}}
# {'before': {'R1': 13.4, 'R3': 29.5, 'R5': 37.6, 'R10': 49.5, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 29.2, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.1, 'R5': 49.9, 'R10': 61.5, 'R50': 86.6, 'MedR': 6.0, 'MeanR': 33.4, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.038}}
# {'before': {'R1': 33.9, 'R3': 53.0, 'R5': 61.3, 'R10': 72.4, 'R50': 92.7, 'MedR': 3.0, 'MeanR': 14.6, 'geometric_mean_R1-R5-R10': 53.2, 'MeanA': 0.257}, 'after': {'R1': 0.0, 'R3': 5.1, 'R5': 7.0, 'R10': 9.2, 'R50': 13.4, 'MedR': 1349.0, 'MeanR': 1807.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.034}}
# {'before': {'R1': 1.2, 'R3': 26.8, 'R5': 36.2, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 12.9, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.9, 'R5': 50.9, 'R10': 62.6, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 44.0, 'MeanA': 0.008}}
# {'before': {'R1': 97.5, 'R3': 99.5, 'R5': 99.7, 'R10': 99.9, 'R50': 100.0, 'MedR': 1.0, 'MeanR': 1.1, 'geometric_mean_R1-R5-R10': 99.0, 'MeanA': 0.361}, 'after': {'R1': 0.0, 'R3': 1.5, 'R5': 1.7, 'R10': 1.8, 'R50': 2.3, 'MedR': 1686.0, 'MeanR': 2168.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.005}}
# {'before': {'R1': 8.1, 'R3': 28.1, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.5, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.5, 'R5': 50.4, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 66.4, 'R3': 79.5, 'R5': 84.2, 'R10': 89.4, 'R50': 97.6, 'MedR': 1.0, 'MeanR': 5.6, 'geometric_mean_R1-R5-R10': 79.3, 'MeanA': 0.293}, 'after': {'R1': 0.0, 'R3': 4.7, 'R5': 6.1, 'R10': 7.8, 'R50': 10.6, 'MedR': 1699.0, 'MeanR': 2095.3, 'geometric_mean_R1-R5-R10': 0.6, 'MeanA': 0.025}}
# {'before': {'R1': 8.2, 'R3': 28.0, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.5, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.2, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.029}}
# {'before': {'R1': 67.3, 'R3': 82.8, 'R5': 87.7, 'R10': 93.0, 'R50': 99.1, 'MedR': 1.0, 'MeanR': 3.8, 'geometric_mean_R1-R5-R10': 81.9, 'MeanA': 0.292}, 'after': {'R1': 0.0, 'R3': 5.2, 'R5': 6.8, 'R10': 8.4, 'R50': 10.4, 'MedR': 1591.5, 'MeanR': 1941.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 6.9, 'R3': 27.6, 'R5': 36.6, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.2, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.4, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.028}}
# {'before': {'R1': 73.8, 'R3': 87.3, 'R5': 91.2, 'R10': 94.9, 'R50': 99.3, 'MedR': 1.0, 'MeanR': 3.3, 'geometric_mean_R1-R5-R10': 86.1, 'MeanA': 0.298}, 'after': {'R1': 0.0, 'R3': 5.1, 'R5': 6.6, 'R10': 7.9, 'R50': 9.6, 'MedR': 1437.0, 'MeanR': 1875.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.024}}
# {'before': {'R1': 9.9, 'R3': 28.4, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.2, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.2, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.1, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.032}}
# {'before': {'R1': 54.5, 'R3': 72.5, 'R5': 78.8, 'R10': 86.1, 'R50': 97.4, 'MedR': 1.0, 'MeanR': 6.6, 'geometric_mean_R1-R5-R10': 71.8, 'MeanA': 0.276}, 'after': {'R1': 0.0, 'R3': 5.4, 'R5': 7.2, 'R10': 8.8, 'R50': 11.0, 'MedR': 1380.0, 'MeanR': 1773.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 13.9, 'R3': 29.6, 'R5': 37.6, 'R10': 49.5, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 29.6, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.0, 'R10': 61.7, 'R50': 86.7, 'MedR': 6.0, 'MeanR': 33.4, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.039}}
# {'before': {'R1': 34.6, 'R3': 52.8, 'R5': 60.8, 'R10': 71.6, 'R50': 93.6, 'MedR': 3.0, 'MeanR': 12.9, 'geometric_mean_R1-R5-R10': 53.2, 'MeanA': 0.256}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.9, 'R10': 9.3, 'R50': 13.7, 'MedR': 1455.0, 'MeanR': 1845.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.034}}
# {'before': {'R1': 2.5, 'R3': 26.9, 'R5': 36.3, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 16.4, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.7, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.013}}
# {'before': {'R1': 93.5, 'R3': 97.8, 'R5': 98.6, 'R10': 99.2, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.3, 'geometric_mean_R1-R5-R10': 97.1, 'MeanA': 0.34}, 'after': {'R1': 0.0, 'R3': 2.6, 'R5': 3.1, 'R10': 3.5, 'R50': 4.3, 'MedR': 1741.0, 'MeanR': 2128.0, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.01}}
# {'before': {'R1': 12.5, 'R3': 29.1, 'R5': 37.3, 'R10': 49.4, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.1, 'R5': 49.9, 'R10': 61.7, 'R50': 86.6, 'MedR': 6.0, 'MeanR': 33.4, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.038}}
# {'before': {'R1': 40.0, 'R3': 59.8, 'R5': 68.2, 'R10': 78.2, 'R50': 95.3, 'MedR': 2.0, 'MeanR': 10.5, 'geometric_mean_R1-R5-R10': 59.8, 'MeanA': 0.264}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.3, 'R10': 9.4, 'R50': 13.6, 'MedR': 1394.5, 'MeanR': 1866.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.033}}
# {'before': {'R1': 8.2, 'R3': 27.8, 'R5': 36.6, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 24.5, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.03}}
# {'before': {'R1': 66.1, 'R3': 83.6, 'R5': 88.8, 'R10': 93.8, 'R50': 99.2, 'MedR': 1.0, 'MeanR': 3.6, 'geometric_mean_R1-R5-R10': 81.9, 'MeanA': 0.287}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.4, 'R10': 8.8, 'R50': 10.4, 'MedR': 1239.5, 'MeanR': 1717.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.027}}
# {'before': {'R1': 5.4, 'R3': 27.4, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.3, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.5, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.022}}
# {'before': {'R1': 81.0, 'R3': 91.7, 'R5': 94.6, 'R10': 97.0, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.3, 'geometric_mean_R1-R5-R10': 90.6, 'MeanA': 0.309}, 'after': {'R1': 0.0, 'R3': 4.6, 'R5': 5.7, 'R10': 6.5, 'R50': 7.8, 'MedR': 1575.0, 'MeanR': 1986.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.019}}
# {'before': {'R1': 5.5, 'R3': 27.5, 'R5': 36.5, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.5, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.022}}
# {'before': {'R1': 78.9, 'R3': 89.5, 'R5': 92.5, 'R10': 95.1, 'R50': 98.9, 'MedR': 1.0, 'MeanR': 3.2, 'geometric_mean_R1-R5-R10': 88.6, 'MeanA': 0.307}, 'after': {'R1': 0.0, 'R3': 4.1, 'R5': 5.2, 'R10': 6.1, 'R50': 7.7, 'MedR': 1621.0, 'MeanR': 2050.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.019}}
# {'before': {'R1': 10.0, 'R3': 28.6, 'R5': 37.0, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.4, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.3, 'R5': 50.1, 'R10': 61.7, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.032}}
# {'before': {'R1': 55.3, 'R3': 71.9, 'R5': 77.8, 'R10': 85.1, 'R50': 97.0, 'MedR': 1.0, 'MeanR': 7.0, 'geometric_mean_R1-R5-R10': 71.5, 'MeanA': 0.278}, 'after': {'R1': 0.0, 'R3': 5.4, 'R5': 7.0, 'R10': 8.7, 'R50': 11.3, 'MedR': 1612.0, 'MeanR': 1945.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 9.0, 'R3': 28.3, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.3, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.03}}
# {'before': {'R1': 60.2, 'R3': 76.7, 'R5': 82.2, 'R10': 88.6, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 5.4, 'geometric_mean_R1-R5-R10': 75.9, 'MeanA': 0.283}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 6.7, 'R10': 8.4, 'R50': 10.9, 'MedR': 1456.0, 'MeanR': 1882.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.027}}
# {'before': {'R1': 5.1, 'R3': 27.4, 'R5': 36.5, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 20.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.6, 'R10': 62.2, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.022}}
# {'before': {'R1': 80.7, 'R3': 91.4, 'R5': 94.2, 'R10': 96.7, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.3, 'geometric_mean_R1-R5-R10': 90.2, 'MeanA': 0.308}, 'after': {'R1': 0.0, 'R3': 4.5, 'R5': 5.6, 'R10': 6.5, 'R50': 7.7, 'MedR': 1450.0, 'MeanR': 1919.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.019}}
# {'before': {'R1': 4.8, 'R3': 27.2, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 20.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.5, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.021}}
# {'before': {'R1': 85.3, 'R3': 94.0, 'R5': 96.1, 'R10': 97.9, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 2.1, 'geometric_mean_R1-R5-R10': 92.9, 'MeanA': 0.317}, 'after': {'R1': 0.0, 'R3': 4.2, 'R5': 5.2, 'R10': 6.0, 'R50': 7.1, 'MedR': 1607.0, 'MeanR': 1979.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.018}}
# {'before': {'R1': 5.8, 'R3': 27.5, 'R5': 36.5, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.8, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.4, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.024}}
# {'before': {'R1': 78.4, 'R3': 89.8, 'R5': 93.0, 'R10': 96.2, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.6, 'geometric_mean_R1-R5-R10': 88.8, 'MeanA': 0.308}, 'after': {'R1': 0.0, 'R3': 4.6, 'R5': 5.7, 'R10': 6.8, 'R50': 8.3, 'MedR': 1592.0, 'MeanR': 1969.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.021}}
# {'before': {'R1': 12.1, 'R3': 28.8, 'R5': 37.1, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.1, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.1, 'R5': 50.0, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.038}}
# {'before': {'R1': 44.7, 'R3': 66.1, 'R5': 74.0, 'R10': 82.9, 'R50': 96.6, 'MedR': 2.0, 'MeanR': 8.1, 'geometric_mean_R1-R5-R10': 65.0, 'MeanA': 0.268}, 'after': {'R1': 0.0, 'R3': 6.0, 'R5': 8.0, 'R10': 10.1, 'R50': 13.3, 'MedR': 1225.0, 'MeanR': 1742.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.034}}
# {'before': {'R1': 15.2, 'R3': 29.9, 'R5': 37.8, 'R10': 49.7, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 30.5, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.1, 'R5': 50.0, 'R10': 61.6, 'R50': 86.6, 'MedR': 5.5, 'MeanR': 33.5, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.04}}
# {'before': {'R1': 25.4, 'R3': 43.9, 'R5': 53.2, 'R10': 65.8, 'R50': 91.7, 'MedR': 5.0, 'MeanR': 15.5, 'geometric_mean_R1-R5-R10': 44.6, 'MeanA': 0.249}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.8, 'R10': 9.4, 'R50': 13.8, 'MedR': 1237.5, 'MeanR': 1638.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.035}}
# {'before': {'R1': 10.8, 'R3': 28.6, 'R5': 37.1, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 27.1, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.1, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.034}}
# {'before': {'R1': 53.0, 'R3': 71.7, 'R5': 78.7, 'R10': 86.2, 'R50': 97.2, 'MedR': 1.0, 'MeanR': 6.8, 'geometric_mean_R1-R5-R10': 71.1, 'MeanA': 0.276}, 'after': {'R1': 0.0, 'R3': 5.7, 'R5': 7.6, 'R10': 9.4, 'R50': 12.3, 'MedR': 1464.0, 'MeanR': 1908.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 12.2, 'R3': 29.1, 'R5': 37.4, 'R10': 49.4, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.3, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.2, 'R5': 50.1, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.1, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.037}}
# {'before': {'R1': 40.9, 'R3': 59.7, 'R5': 67.8, 'R10': 78.2, 'R50': 94.8, 'MedR': 2.0, 'MeanR': 10.5, 'geometric_mean_R1-R5-R10': 60.1, 'MeanA': 0.265}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.2, 'R10': 9.4, 'R50': 13.5, 'MedR': 1426.0, 'MeanR': 1898.0, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.033}}
# {'before': {'R1': 2.7, 'R3': 27.0, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 16.8, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.7, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.014}}
# {'before': {'R1': 92.2, 'R3': 97.0, 'R5': 98.0, 'R10': 98.9, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.5, 'geometric_mean_R1-R5-R10': 96.3, 'MeanA': 0.341}, 'after': {'R1': 0.0, 'R3': 2.7, 'R5': 3.2, 'R10': 3.7, 'R50': 4.7, 'MedR': 1971.5, 'MeanR': 2262.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.011}}
# {'before': {'R1': 2.9, 'R3': 27.1, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 17.2, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.9, 'R5': 50.8, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.015}}
# {'before': {'R1': 91.1, 'R3': 96.7, 'R5': 97.8, 'R10': 98.8, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.6, 'geometric_mean_R1-R5-R10': 95.8, 'MeanA': 0.334}, 'after': {'R1': 0.0, 'R3': 3.1, 'R5': 3.7, 'R10': 4.2, 'R50': 5.0, 'MedR': 1668.5, 'MeanR': 2081.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.012}}
# {'before': {'R1': 7.8, 'R3': 28.0, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.1, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 70.2, 'R3': 83.0, 'R5': 87.2, 'R10': 91.8, 'R50': 98.5, 'MedR': 1.0, 'MeanR': 4.4, 'geometric_mean_R1-R5-R10': 82.5, 'MeanA': 0.295}, 'after': {'R1': 0.0, 'R3': 4.8, 'R5': 6.3, 'R10': 7.7, 'R50': 10.0, 'MedR': 1514.0, 'MeanR': 1939.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.025}}
# {'before': {'R1': 2.3, 'R3': 26.9, 'R5': 36.3, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 15.9, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.8, 'R10': 62.5, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 44.0, 'MeanA': 0.013}}
# {'before': {'R1': 94.6, 'R3': 98.2, 'R5': 98.9, 'R10': 99.4, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.4, 'geometric_mean_R1-R5-R10': 97.6, 'MeanA': 0.341}, 'after': {'R1': 0.0, 'R3': 2.5, 'R5': 3.0, 'R10': 3.3, 'R50': 3.9, 'MedR': 1625.0, 'MeanR': 2094.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.01}}
# {'before': {'R1': 9.3, 'R3': 28.2, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.7, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.3, 'R5': 50.1, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.4, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.031}}
# {'before': {'R1': 56.0, 'R3': 73.1, 'R5': 79.0, 'R10': 86.1, 'R50': 97.2, 'MedR': 1.0, 'MeanR': 6.9, 'geometric_mean_R1-R5-R10': 72.5, 'MeanA': 0.279}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 6.8, 'R10': 8.6, 'R50': 11.4, 'MedR': 1500.5, 'MeanR': 1914.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 11.0, 'R3': 28.6, 'R5': 37.0, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 27.2, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.2, 'R5': 50.1, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.034}}
# {'before': {'R1': 51.9, 'R3': 71.3, 'R5': 78.5, 'R10': 87.1, 'R50': 97.9, 'MedR': 1.0, 'MeanR': 6.1, 'geometric_mean_R1-R5-R10': 70.8, 'MeanA': 0.274}, 'after': {'R1': 0.0, 'R3': 6.0, 'R5': 7.7, 'R10': 9.7, 'R50': 12.2, 'MedR': 1427.5, 'MeanR': 1758.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 9.0, 'R3': 28.1, 'R5': 36.8, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.3, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.5, 'R5': 50.3, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.032}}
# {'before': {'R1': 63.9, 'R3': 80.6, 'R5': 85.9, 'R10': 91.8, 'R50': 98.6, 'MedR': 1.0, 'MeanR': 4.3, 'geometric_mean_R1-R5-R10': 79.6, 'MeanA': 0.287}, 'after': {'R1': 0.0, 'R3': 6.0, 'R5': 7.5, 'R10': 9.2, 'R50': 11.4, 'MedR': 1495.5, 'MeanR': 1962.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.028}}
# {'before': {'R1': 4.5, 'R3': 27.3, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 20.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.021}}
# {'before': {'R1': 83.9, 'R3': 93.0, 'R5': 95.4, 'R10': 97.5, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.2, 'geometric_mean_R1-R5-R10': 92.1, 'MeanA': 0.315}, 'after': {'R1': 0.0, 'R3': 4.1, 'R5': 5.0, 'R10': 5.8, 'R50': 7.1, 'MedR': 1549.0, 'MeanR': 1995.8, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.018}}
# {'before': {'R1': 8.4, 'R3': 28.0, 'R5': 36.8, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.8, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.3, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.03}}
# {'before': {'R1': 64.1, 'R3': 79.7, 'R5': 84.9, 'R10': 90.7, 'R50': 98.4, 'MedR': 1.0, 'MeanR': 4.7, 'geometric_mean_R1-R5-R10': 79.0, 'MeanA': 0.288}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 6.9, 'R10': 8.4, 'R50': 10.5, 'MedR': 1426.0, 'MeanR': 1783.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 10.4, 'R3': 28.2, 'R5': 37.0, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.6, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.2, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.034}}
# {'before': {'R1': 57.6, 'R3': 76.5, 'R5': 83.0, 'R10': 89.9, 'R50': 98.9, 'MedR': 1.0, 'MeanR': 4.7, 'geometric_mean_R1-R5-R10': 75.5, 'MeanA': 0.28}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.7, 'R10': 9.6, 'R50': 12.1, 'MedR': 1325.0, 'MeanR': 1750.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 3.1, 'R3': 27.1, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 17.6, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.7, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.015}}
# {'before': {'R1': 90.4, 'R3': 96.2, 'R5': 97.5, 'R10': 98.5, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.6, 'geometric_mean_R1-R5-R10': 95.4, 'MeanA': 0.328}, 'after': {'R1': 0.0, 'R3': 3.2, 'R5': 3.8, 'R10': 4.3, 'R50': 5.2, 'MedR': 1649.0, 'MeanR': 2088.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.012}}
# {'before': {'R1': 9.9, 'R3': 28.2, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.2, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.2, 'R5': 50.2, 'R10': 61.9, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.034}}
# {'before': {'R1': 55.6, 'R3': 74.9, 'R5': 81.1, 'R10': 87.9, 'R50': 97.7, 'MedR': 1.0, 'MeanR': 7.0, 'geometric_mean_R1-R5-R10': 73.5, 'MeanA': 0.278}, 'after': {'R1': 0.0, 'R3': 6.3, 'R5': 7.9, 'R10': 9.6, 'R50': 12.3, 'MedR': 1186.5, 'MeanR': 1762.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 12.0, 'R3': 28.8, 'R5': 37.1, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.1, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.035}}
# {'before': {'R1': 45.4, 'R3': 66.4, 'R5': 74.2, 'R10': 83.6, 'R50': 97.8, 'MedR': 2.0, 'MeanR': 7.1, 'geometric_mean_R1-R5-R10': 65.6, 'MeanA': 0.268}, 'after': {'R1': 0.0, 'R3': 5.7, 'R5': 7.4, 'R10': 9.6, 'R50': 12.5, 'MedR': 1246.0, 'MeanR': 1664.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 11.8, 'R3': 28.8, 'R5': 37.2, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 27.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.2, 'R5': 50.1, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.2, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.037}}
# {'before': {'R1': 47.8, 'R3': 67.4, 'R5': 74.1, 'R10': 83.1, 'R50': 96.6, 'MedR': 2.0, 'MeanR': 8.1, 'geometric_mean_R1-R5-R10': 66.5, 'MeanA': 0.27}, 'after': {'R1': 0.0, 'R3': 6.0, 'R5': 7.7, 'R10': 9.8, 'R50': 12.8, 'MedR': 1329.0, 'MeanR': 1765.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.033}}
# {'before': {'R1': 3.9, 'R3': 27.1, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.1, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.6, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.018}}
# {'before': {'R1': 88.1, 'R3': 95.3, 'R5': 97.0, 'R10': 98.5, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.7, 'geometric_mean_R1-R5-R10': 94.4, 'MeanA': 0.325}, 'after': {'R1': 0.0, 'R3': 3.7, 'R5': 4.4, 'R10': 5.1, 'R50': 6.0, 'MedR': 1659.5, 'MeanR': 2046.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.015}}
# {'before': {'R1': 10.2, 'R3': 28.3, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.033}}
# {'before': {'R1': 56.9, 'R3': 75.7, 'R5': 81.9, 'R10': 89.2, 'R50': 98.6, 'MedR': 1.0, 'MeanR': 5.1, 'geometric_mean_R1-R5-R10': 74.6, 'MeanA': 0.279}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.6, 'R10': 9.3, 'R50': 11.7, 'MedR': 1294.0, 'MeanR': 1693.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.029}}
# {'before': {'R1': 4.4, 'R3': 27.3, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.9, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.6, 'R10': 62.2, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.02}}
# {'before': {'R1': 85.2, 'R3': 93.3, 'R5': 95.4, 'R10': 97.5, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 2.0, 'geometric_mean_R1-R5-R10': 92.5, 'MeanA': 0.319}, 'after': {'R1': 0.0, 'R3': 3.9, 'R5': 4.9, 'R10': 5.8, 'R50': 7.3, 'MedR': 1663.0, 'MeanR': 2103.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.017}}
# {'before': {'R1': 12.0, 'R3': 28.8, 'R5': 37.2, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.3, 'R10': 62.0, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.038}}
# {'before': {'R1': 50.3, 'R3': 68.1, 'R5': 74.6, 'R10': 82.5, 'R50': 95.4, 'MedR': 1.0, 'MeanR': 9.9, 'geometric_mean_R1-R5-R10': 67.7, 'MeanA': 0.273}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.3, 'R10': 9.3, 'R50': 12.9, 'MedR': 1269.5, 'MeanR': 1845.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.033}}
# {'before': {'R1': 7.6, 'R3': 27.8, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.4, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.028}}
# {'before': {'R1': 69.5, 'R3': 83.4, 'R5': 87.6, 'R10': 92.3, 'R50': 98.8, 'MedR': 1.0, 'MeanR': 4.0, 'geometric_mean_R1-R5-R10': 82.5, 'MeanA': 0.294}, 'after': {'R1': 0.0, 'R3': 5.0, 'R5': 6.3, 'R10': 7.5, 'R50': 9.5, 'MedR': 1517.0, 'MeanR': 1867.0, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.024}}
# {'before': {'R1': 9.8, 'R3': 28.2, 'R5': 36.9, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.1, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.4, 'R5': 50.3, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.033}}
# {'before': {'R1': 56.0, 'R3': 76.6, 'R5': 83.4, 'R10': 90.6, 'R50': 98.8, 'MedR': 1.0, 'MeanR': 4.6, 'geometric_mean_R1-R5-R10': 75.1, 'MeanA': 0.278}, 'after': {'R1': 0.0, 'R3': 6.3, 'R5': 8.1, 'R10': 9.9, 'R50': 11.8, 'MedR': 1140.0, 'MeanR': 1579.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.03}}
# {'before': {'R1': 9.7, 'R3': 28.2, 'R5': 36.9, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 26.0, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.033}}
# {'before': {'R1': 59.9, 'R3': 77.8, 'R5': 83.3, 'R10': 89.9, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 5.2, 'geometric_mean_R1-R5-R10': 76.6, 'MeanA': 0.282}, 'after': {'R1': 0.0, 'R3': 5.8, 'R5': 7.4, 'R10': 9.1, 'R50': 11.5, 'MedR': 1305.0, 'MeanR': 1787.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.029}}
# {'before': {'R1': 2.2, 'R3': 26.9, 'R5': 36.3, 'R10': 48.9, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 15.7, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.8, 'R10': 62.5, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 44.0, 'MeanA': 0.012}}
# {'before': {'R1': 93.7, 'R3': 97.6, 'R5': 98.4, 'R10': 99.1, 'R50': 99.9, 'MedR': 1.0, 'MeanR': 1.4, 'geometric_mean_R1-R5-R10': 97.0, 'MeanA': 0.347}, 'after': {'R1': 0.0, 'R3': 2.3, 'R5': 2.7, 'R10': 3.1, 'R50': 3.9, 'MedR': 1951.0, 'MeanR': 2237.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.009}}
# {'before': {'R1': 8.6, 'R3': 28.2, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.03}}
# {'before': {'R1': 64.8, 'R3': 78.6, 'R5': 83.3, 'R10': 88.7, 'R50': 97.2, 'MedR': 1.0, 'MeanR': 6.3, 'geometric_mean_R1-R5-R10': 78.2, 'MeanA': 0.29}, 'after': {'R1': 0.0, 'R3': 5.0, 'R5': 6.4, 'R10': 7.9, 'R50': 11.3, 'MedR': 1579.0, 'MeanR': 2087.2, 'geometric_mean_R1-R5-R10': 0.6, 'MeanA': 0.026}}
# {'before': {'R1': 14.6, 'R3': 29.9, 'R5': 37.7, 'R10': 49.7, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 30.2, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.1, 'R5': 50.0, 'R10': 61.5, 'R50': 86.6, 'MedR': 6.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.039}}
# {'before': {'R1': 27.6, 'R3': 45.0, 'R5': 53.1, 'R10': 65.3, 'R50': 90.9, 'MedR': 5.0, 'MeanR': 17.0, 'geometric_mean_R1-R5-R10': 45.7, 'MeanA': 0.249}, 'after': {'R1': 0.0, 'R3': 4.5, 'R5': 6.3, 'R10': 8.7, 'R50': 13.3, 'MedR': 1327.5, 'MeanR': 1766.6, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.034}}
# {'before': {'R1': 11.6, 'R3': 28.8, 'R5': 37.2, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 27.7, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.1, 'R10': 61.8, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.036}}
# {'before': {'R1': 46.4, 'R3': 65.9, 'R5': 73.1, 'R10': 82.3, 'R50': 97.1, 'MedR': 2.0, 'MeanR': 7.8, 'geometric_mean_R1-R5-R10': 65.3, 'MeanA': 0.27}, 'after': {'R1': 0.0, 'R3': 5.9, 'R5': 7.7, 'R10': 9.6, 'R50': 12.5, 'MedR': 1347.0, 'MeanR': 1773.2, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.032}}
# {'before': {'R1': 6.5, 'R3': 27.7, 'R5': 36.6, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 22.7, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.4, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.025}}
# {'before': {'R1': 76.4, 'R3': 87.4, 'R5': 91.1, 'R10': 94.8, 'R50': 99.3, 'MedR': 1.0, 'MeanR': 3.1, 'geometric_mean_R1-R5-R10': 87.1, 'MeanA': 0.306}, 'after': {'R1': 0.0, 'R3': 4.4, 'R5': 5.8, 'R10': 7.0, 'R50': 8.9, 'MedR': 1777.0, 'MeanR': 2099.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.021}}
# {'before': {'R1': 2.9, 'R3': 27.0, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.9, 'geometric_mean_R1-R5-R10': 17.3, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.7, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.016}}
# {'before': {'R1': 90.9, 'R3': 96.6, 'R5': 97.8, 'R10': 98.9, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.6, 'geometric_mean_R1-R5-R10': 95.8, 'MeanA': 0.333}, 'after': {'R1': 0.0, 'R3': 3.2, 'R5': 3.8, 'R10': 4.4, 'R50': 5.6, 'MedR': 1820.0, 'MeanR': 2194.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.013}}
# {'before': {'R1': 5.2, 'R3': 27.4, 'R5': 36.5, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.0, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.6, 'R5': 50.6, 'R10': 62.3, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.022}}
# {'before': {'R1': 81.8, 'R3': 91.3, 'R5': 94.1, 'R10': 96.6, 'R50': 99.5, 'MedR': 1.0, 'MeanR': 2.4, 'geometric_mean_R1-R5-R10': 90.6, 'MeanA': 0.314}, 'after': {'R1': 0.0, 'R3': 4.3, 'R5': 5.4, 'R10': 6.3, 'R50': 7.7, 'MedR': 1699.5, 'MeanR': 2101.8, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.019}}
# {'before': {'R1': 7.9, 'R3': 28.0, 'R5': 36.8, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 24.3, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.3, 'R10': 61.9, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.029}}
# {'before': {'R1': 66.8, 'R3': 80.9, 'R5': 85.6, 'R10': 91.0, 'R50': 98.7, 'MedR': 1.0, 'MeanR': 4.5, 'geometric_mean_R1-R5-R10': 80.4, 'MeanA': 0.292}, 'after': {'R1': 0.0, 'R3': 5.0, 'R5': 6.5, 'R10': 7.9, 'R50': 10.1, 'MedR': 1644.0, 'MeanR': 1960.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.025}}
# {'before': {'R1': 18.3, 'R3': 31.7, 'R5': 38.9, 'R10': 50.3, 'R50': 79.9, 'MedR': 10.0, 'MeanR': 48.2, 'geometric_mean_R1-R5-R10': 32.9, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.1, 'R5': 49.9, 'R10': 61.4, 'R50': 86.5, 'MedR': 6.0, 'MeanR': 33.7, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.044}}
# {'before': {'R1': 4.6, 'R3': 12.5, 'R5': 18.3, 'R10': 29.6, 'R50': 67.3, 'MedR': 26.0, 'MeanR': 52.4, 'geometric_mean_R1-R5-R10': 13.6, 'MeanA': 0.215}, 'after': {'R1': 0.0, 'R3': 1.9, 'R5': 3.3, 'R10': 5.6, 'R50': 12.0, 'MedR': 1263.0, 'MeanR': 1648.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.035}}
# {'before': {'R1': 11.0, 'R3': 28.8, 'R5': 37.1, 'R10': 49.4, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 27.2, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.1, 'R10': 61.7, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.035}}
# {'before': {'R1': 49.0, 'R3': 66.5, 'R5': 73.4, 'R10': 81.7, 'R50': 95.2, 'MedR': 2.0, 'MeanR': 10.0, 'geometric_mean_R1-R5-R10': 66.5, 'MeanA': 0.271}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.4, 'R10': 9.4, 'R50': 12.4, 'MedR': 1463.0, 'MeanR': 1899.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 6.5, 'R3': 27.6, 'R5': 36.6, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 22.7, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.6, 'R5': 50.5, 'R10': 62.2, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.026}}
# {'before': {'R1': 75.8, 'R3': 87.8, 'R5': 91.2, 'R10': 94.7, 'R50': 99.1, 'MedR': 1.0, 'MeanR': 3.2, 'geometric_mean_R1-R5-R10': 86.8, 'MeanA': 0.303}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.2, 'R10': 7.4, 'R50': 9.2, 'MedR': 1560.5, 'MeanR': 1999.0, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.023}}
# {'before': {'R1': 9.5, 'R3': 28.3, 'R5': 36.9, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.8, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.2, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.1, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.033}}
# {'before': {'R1': 57.8, 'R3': 74.3, 'R5': 80.2, 'R10': 86.5, 'R50': 96.7, 'MedR': 1.0, 'MeanR': 7.2, 'geometric_mean_R1-R5-R10': 73.7, 'MeanA': 0.281}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.0, 'R10': 8.6, 'R50': 11.6, 'MedR': 1552.0, 'MeanR': 1970.5, 'geometric_mean_R1-R5-R10': 0.6, 'MeanA': 0.029}}
# {'before': {'R1': 11.9, 'R3': 28.9, 'R5': 37.2, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.0, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.0, 'R10': 61.6, 'R50': 86.7, 'MedR': 6.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.4, 'MeanA': 0.037}}
# {'before': {'R1': 45.1, 'R3': 63.2, 'R5': 70.9, 'R10': 80.5, 'R50': 95.5, 'MedR': 2.0, 'MeanR': 9.4, 'geometric_mean_R1-R5-R10': 63.6, 'MeanA': 0.267}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.3, 'R10': 9.4, 'R50': 12.9, 'MedR': 1500.5, 'MeanR': 1837.8, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.032}}
# {'before': {'R1': 8.1, 'R3': 27.9, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 24.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.4, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 69.7, 'R3': 83.9, 'R5': 88.7, 'R10': 93.4, 'R50': 99.0, 'MedR': 1.0, 'MeanR': 3.8, 'geometric_mean_R1-R5-R10': 83.3, 'MeanA': 0.294}, 'after': {'R1': 0.0, 'R3': 5.5, 'R5': 7.0, 'R10': 8.5, 'R50': 10.3, 'MedR': 1626.0, 'MeanR': 1984.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 5.0, 'R3': 27.3, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 20.7, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.021}}
# {'before': {'R1': 83.4, 'R3': 92.8, 'R5': 95.1, 'R10': 97.3, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.1, 'geometric_mean_R1-R5-R10': 91.7, 'MeanA': 0.313}, 'after': {'R1': 0.0, 'R3': 4.3, 'R5': 5.3, 'R10': 6.2, 'R50': 7.1, 'MedR': 1496.0, 'MeanR': 1937.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.018}}
# {'before': {'R1': 11.5, 'R3': 28.8, 'R5': 37.2, 'R10': 49.3, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 27.6, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.3, 'R5': 50.3, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.035}}
# {'before': {'R1': 48.8, 'R3': 67.1, 'R5': 74.4, 'R10': 82.6, 'R50': 95.7, 'MedR': 2.0, 'MeanR': 8.7, 'geometric_mean_R1-R5-R10': 66.9, 'MeanA': 0.271}, 'after': {'R1': 0.0, 'R3': 5.4, 'R5': 7.1, 'R10': 9.2, 'R50': 12.3, 'MedR': 1302.0, 'MeanR': 1801.1, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.031}}
# {'before': {'R1': 4.1, 'R3': 27.2, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.6, 'R10': 62.3, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.018}}
# {'before': {'R1': 86.2, 'R3': 93.7, 'R5': 95.8, 'R10': 97.7, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 2.0, 'geometric_mean_R1-R5-R10': 93.1, 'MeanA': 0.32}, 'after': {'R1': 0.0, 'R3': 3.5, 'R5': 4.4, 'R10': 5.1, 'R50': 6.1, 'MedR': 1648.0, 'MeanR': 2061.7, 'geometric_mean_R1-R5-R10': 0.4, 'MeanA': 0.015}}
# {'before': {'R1': 7.1, 'R3': 27.9, 'R5': 36.7, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.4, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.4, 'R10': 62.0, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.027}}
# {'before': {'R1': 70.5, 'R3': 83.2, 'R5': 87.1, 'R10': 91.7, 'R50': 98.4, 'MedR': 1.0, 'MeanR': 4.4, 'geometric_mean_R1-R5-R10': 82.5, 'MeanA': 0.295}, 'after': {'R1': 0.0, 'R3': 4.8, 'R5': 6.1, 'R10': 7.6, 'R50': 9.7, 'MedR': 1571.0, 'MeanR': 1983.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.024}}
# {'before': {'R1': 6.8, 'R3': 27.6, 'R5': 36.5, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.0, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.5, 'R5': 50.4, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.025}}
# {'before': {'R1': 74.6, 'R3': 88.1, 'R5': 91.8, 'R10': 95.6, 'R50': 99.5, 'MedR': 1.0, 'MeanR': 2.7, 'geometric_mean_R1-R5-R10': 86.8, 'MeanA': 0.299}, 'after': {'R1': 0.0, 'R3': 4.9, 'R5': 6.1, 'R10': 7.2, 'R50': 8.5, 'MedR': 1456.0, 'MeanR': 1852.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.022}}
# {'before': {'R1': 3.7, 'R3': 27.2, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 18.7, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.7, 'R5': 50.6, 'R10': 62.3, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.017}}
# {'before': {'R1': 87.9, 'R3': 94.6, 'R5': 96.3, 'R10': 97.7, 'R50': 99.6, 'MedR': 1.0, 'MeanR': 2.0, 'geometric_mean_R1-R5-R10': 93.9, 'MeanA': 0.327}, 'after': {'R1': 0.0, 'R3': 3.5, 'R5': 4.2, 'R10': 4.8, 'R50': 5.6, 'MedR': 1924.0, 'MeanR': 2209.0, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.014}}
# {'before': {'R1': 5.4, 'R3': 27.4, 'R5': 36.5, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 21.3, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.7, 'R5': 50.6, 'R10': 62.2, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.5, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.023}}
# {'before': {'R1': 80.9, 'R3': 91.3, 'R5': 94.1, 'R10': 96.5, 'R50': 99.5, 'MedR': 1.0, 'MeanR': 2.5, 'geometric_mean_R1-R5-R10': 90.2, 'MeanA': 0.309}, 'after': {'R1': 0.0, 'R3': 4.7, 'R5': 5.8, 'R10': 6.8, 'R50': 8.5, 'MedR': 1445.0, 'MeanR': 1946.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.02}}
# {'before': {'R1': 15.2, 'R3': 29.9, 'R5': 37.8, 'R10': 49.6, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.5, 'geometric_mean_R1-R5-R10': 30.6, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.1, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.04}}
# {'before': {'R1': 27.4, 'R3': 47.1, 'R5': 56.5, 'R10': 68.6, 'R50': 92.4, 'MedR': 4.0, 'MeanR': 14.6, 'geometric_mean_R1-R5-R10': 47.4, 'MeanA': 0.25}, 'after': {'R1': 0.0, 'R3': 4.7, 'R5': 6.7, 'R10': 9.2, 'R50': 13.7, 'MedR': 1207.0, 'MeanR': 1628.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.034}}
# {'before': {'R1': 4.0, 'R3': 27.2, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.2, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.6, 'R10': 62.2, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.019}}
# {'before': {'R1': 85.7, 'R3': 93.5, 'R5': 95.4, 'R10': 97.3, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 2.2, 'geometric_mean_R1-R5-R10': 92.6, 'MeanA': 0.324}, 'after': {'R1': 0.0, 'R3': 3.7, 'R5': 4.5, 'R10': 5.4, 'R50': 6.9, 'MedR': 1813.0, 'MeanR': 2141.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.016}}
# {'before': {'R1': 4.3, 'R3': 27.3, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 19.8, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.6, 'R10': 62.3, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.02}}
# {'before': {'R1': 83.8, 'R3': 92.4, 'R5': 95.0, 'R10': 97.4, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 2.1, 'geometric_mean_R1-R5-R10': 91.9, 'MeanA': 0.319}, 'after': {'R1': 0.0, 'R3': 3.8, 'R5': 4.7, 'R10': 5.5, 'R50': 7.2, 'MedR': 1863.0, 'MeanR': 2177.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.017}}
# {'before': {'R1': 12.0, 'R3': 28.8, 'R5': 37.1, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 27.9, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.1, 'R10': 61.8, 'R50': 86.8, 'MedR': 5.0, 'MeanR': 33.3, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.036}}
# {'before': {'R1': 47.8, 'R3': 68.9, 'R5': 76.9, 'R10': 86.2, 'R50': 98.0, 'MedR': 2.0, 'MeanR': 6.1, 'geometric_mean_R1-R5-R10': 68.2, 'MeanA': 0.271}, 'after': {'R1': 0.0, 'R3': 6.1, 'R5': 8.0, 'R10': 10.1, 'R50': 12.9, 'MedR': 1374.0, 'MeanR': 1768.7, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.032}}
# {'before': {'R1': 12.2, 'R3': 29.2, 'R5': 37.4, 'R10': 49.4, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.6, 'geometric_mean_R1-R5-R10': 28.3, 'MeanA': 0.236}, 'after': {'R1': 26.6, 'R3': 42.2, 'R5': 50.1, 'R10': 61.7, 'R50': 86.7, 'MedR': 5.0, 'MeanR': 33.4, 'geometric_mean_R1-R5-R10': 43.5, 'MeanA': 0.036}}
# {'before': {'R1': 41.5, 'R3': 59.5, 'R5': 67.2, 'R10': 77.0, 'R50': 94.3, 'MedR': 2.0, 'MeanR': 10.9, 'geometric_mean_R1-R5-R10': 59.9, 'MeanA': 0.264}, 'after': {'R1': 0.0, 'R3': 5.3, 'R5': 7.0, 'R10': 9.1, 'R50': 12.8, 'MedR': 1495.0, 'MeanR': 1843.4, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.032}}
# {'before': {'R1': 6.2, 'R3': 27.6, 'R5': 36.6, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 22.3, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.3, 'R10': 62.0, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.1, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.025}}
# {'before': {'R1': 76.6, 'R3': 87.7, 'R5': 91.0, 'R10': 94.7, 'R50': 99.1, 'MedR': 1.0, 'MeanR': 3.3, 'geometric_mean_R1-R5-R10': 87.1, 'MeanA': 0.306}, 'after': {'R1': 0.0, 'R3': 4.5, 'R5': 5.8, 'R10': 7.1, 'R50': 8.8, 'MedR': 1668.0, 'MeanR': 2040.5, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.022}}
# {'before': {'R1': 7.2, 'R3': 27.8, 'R5': 36.6, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 23.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.4, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.6, 'geometric_mean_R1-R5-R10': 43.7, 'MeanA': 0.029}}
# {'before': {'R1': 71.6, 'R3': 85.6, 'R5': 90.2, 'R10': 94.5, 'R50': 99.3, 'MedR': 1.0, 'MeanR': 3.1, 'geometric_mean_R1-R5-R10': 84.8, 'MeanA': 0.296}, 'after': {'R1': 0.0, 'R3': 5.6, 'R5': 7.2, 'R10': 8.6, 'R50': 10.5, 'MedR': 1495.0, 'MeanR': 1907.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}
# {'before': {'R1': 4.5, 'R3': 27.2, 'R5': 36.4, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 20.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.6, 'R5': 50.5, 'R10': 62.2, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.8, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.021}}
# {'before': {'R1': 84.3, 'R3': 93.3, 'R5': 95.5, 'R10': 97.5, 'R50': 99.8, 'MedR': 1.0, 'MeanR': 1.9, 'geometric_mean_R1-R5-R10': 92.3, 'MeanA': 0.315}, 'after': {'R1': 0.0, 'R3': 4.4, 'R5': 5.4, 'R10': 6.2, 'R50': 7.2, 'MedR': 1542.0, 'MeanR': 1986.3, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.018}}
# {'before': {'R1': 3.3, 'R3': 27.1, 'R5': 36.3, 'R10': 49.0, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 18.1, 'MeanA': 0.236}, 'after': {'R1': 26.8, 'R3': 42.8, 'R5': 50.7, 'R10': 62.4, 'R50': 87.0, 'MedR': 5.0, 'MeanR': 32.7, 'geometric_mean_R1-R5-R10': 43.9, 'MeanA': 0.017}}
# {'before': {'R1': 90.0, 'R3': 95.8, 'R5': 97.2, 'R10': 98.4, 'R50': 99.7, 'MedR': 1.0, 'MeanR': 1.7, 'geometric_mean_R1-R5-R10': 95.1, 'MeanA': 0.332}, 'after': {'R1': 0.0, 'R3': 3.2, 'R5': 3.9, 'R10': 4.6, 'R50': 5.9, 'MedR': 1828.0, 'MeanR': 2220.8, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.014}}
# {'before': {'R1': 7.7, 'R3': 27.8, 'R5': 36.6, 'R10': 49.1, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.8, 'geometric_mean_R1-R5-R10': 24.0, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.5, 'R5': 50.5, 'R10': 62.1, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 32.9, 'geometric_mean_R1-R5-R10': 43.8, 'MeanA': 0.028}}
# {'before': {'R1': 70.9, 'R3': 85.1, 'R5': 89.0, 'R10': 93.3, 'R50': 98.8, 'MedR': 1.0, 'MeanR': 3.9, 'geometric_mean_R1-R5-R10': 83.8, 'MeanA': 0.296}, 'after': {'R1': 0.0, 'R3': 5.2, 'R5': 6.6, 'R10': 8.0, 'R50': 10.0, 'MedR': 1544.0, 'MeanR': 2024.4, 'geometric_mean_R1-R5-R10': 0.6, 'MeanA': 0.025}}
# {'before': {'R1': 9.1, 'R3': 28.3, 'R5': 36.8, 'R10': 49.2, 'R50': 79.8, 'MedR': 11.0, 'MeanR': 48.7, 'geometric_mean_R1-R5-R10': 25.5, 'MeanA': 0.236}, 'after': {'R1': 26.7, 'R3': 42.4, 'R5': 50.2, 'R10': 61.9, 'R50': 86.9, 'MedR': 5.0, 'MeanR': 33.0, 'geometric_mean_R1-R5-R10': 43.6, 'MeanA': 0.03}}
# {'before': {'R1': 59.3, 'R3': 75.5, 'R5': 81.3, 'R10': 88.4, 'R50': 98.3, 'MedR': 1.0, 'MeanR': 5.7, 'geometric_mean_R1-R5-R10': 75.3, 'MeanA': 0.282}, 'after': {'R1': 0.0, 'R3': 5.0, 'R5': 6.6, 'R10': 8.1, 'R50': 10.4, 'MedR': 1423.0, 'MeanR': 1791.9, 'geometric_mean_R1-R5-R10': 0.0, 'MeanA': 0.026}}

# %%
# save the metrics to a file
with open(f'{out_dir}/gt_metrics.pkl', 'wb') as f:
    pkl.dump(gt_metrics, f)
with open(f'{out_dir}/adv_metrics.pkl', 'wb') as f:
    pkl.dump(adv_metrics, f)

# %%
# load the metrics from the file
with open(f'{out_dir}/gt_metrics.pkl', 'rb') as f:
    temp_gt_metrics = pkl.load(f)
with open(f'{out_dir}/adv_metrics.pkl', 'rb') as f:
    temp_adv_metrics = pkl.load(f)

def post_analysis(data):
    # Initialize dictionaries to hold lists of metric values across entries
    metrics_before = {key: [] for key in data[0]['before']}
    metrics_after = {key: [] for key in data[0]['after']}

    # Collect all metric values for each metric type across all entries
    for entry in data.values():
        for metric, value in entry['before'].items():
            metrics_before[metric].append(value)
        for metric, value in entry['after'].items():
            metrics_after[metric].append(value)

    # Function to calculate mean and standard deviation
    def calculate_stats(metrics_dict):
        stats = {}
        for metric, values in metrics_dict.items():
            avg = round(np.mean(values), 1)
            std_dev = round(np.std(values), 1)
            stats[metric] = {'average': avg, 'std_dev': std_dev}
        return stats

    # Calculate stats for 'before' and 'after'
    before_stats = calculate_stats(metrics_before)
    after_stats = calculate_stats(metrics_after)

    return before_stats, after_stats

print("gt stats:", post_analysis(temp_gt_metrics))
print("adv stats:", post_analysis(temp_adv_metrics))
# Out:
# gt stats: ({'R1': {'average': 8.2, 'std_dev': 3.6}, 'R3': {'average': 28.1, 'std_dev': 0.9}, 'R5': {'average': 36.8, 'std_dev': 0.4}, 'R10': {'average': 49.2, 'std_dev': 0.2}, 'R50': {'average': 79.8, 'std_dev': 0.0}, 'MedR': {'average': 11.0, 'std_dev': 0.1}, 'MeanR': {'average': 48.7, 'std_dev': 0.1}, 'geometric_mean_R1-R5-R10': {'average': 23.9, 'std_dev': 4.1}, 'MeanA': {'average': 0.2, 'std_dev': 0.0}}, {'R1': {'average': 26.7, 'std_dev': 0.1}, 'R3': {'average': 42.4, 'std_dev': 0.2}, 'R5': {'average': 50.3, 'std_dev': 0.2}, 'R10': {'average': 62.0, 'std_dev': 0.3}, 'R50': {'average': 86.9, 'std_dev': 0.1}, 'MedR': {'average': 5.1, 'std_dev': 0.2}, 'MeanR': {'average': 32.9, 'std_dev': 0.2}, 'geometric_mean_R1-R5-R10': {'average': 43.7, 'std_dev': 0.2}, 'MeanA': {'average': 0.0, 'std_dev': 0.0}})
# adv stats: ({'R1': {'average': 65.5, 'std_dev': 19.1}, 'R3': {'average': 79.2, 'std_dev': 15.2}, 'R5': {'average': 83.9, 'std_dev': 13.2}, 'R10': {'average': 89.3, 'std_dev': 10.3}, 'R50': {'average': 97.7, 'std_dev': 3.7}, 'MedR': {'average': 1.6, 'std_dev': 2.6}, 'MeanR': {'average': 5.8, 'std_dev': 6.0}, 'geometric_mean_R1-R5-R10': {'average': 78.6, 'std_dev': 14.9}, 'MeanA': {'average': 0.3, 'std_dev': 0.0}}, {'R1': {'average': 0.0, 'std_dev': 0.0}, 'R3': {'average': 4.8, 'std_dev': 1.1}, 'R5': {'average': 6.2, 'std_dev': 1.5}, 'R10': {'average': 7.6, 'std_dev': 2.0}, 'R50': {'average': 9.8, 'std_dev': 2.9}, 'MedR': {'average': 1501.4, 'std_dev': 185.3}, 'MeanR': {'average': 1921.9, 'std_dev': 155.3}, 'geometric_mean_R1-R5-R10': {'average': 0.0, 'std_dev': 0.1}, 'MeanA': {'average': 0.0, 'std_dev': 0.0}})
